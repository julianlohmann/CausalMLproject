# %%
# import the required packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# load the data for Germany
df = pd.read_csv("pisa_germany_2022.csv")

# %%
# select the relevant variables for this project

varlist = [
    "preedu", # treatment / exposure
    "Ach", # outcome
    "GENDER", "AGE", "IMMIG", "HISCED", "HOMEPOS", "ESCS", "CREATHME", # Covariates / Controls
    "PA185Q08JA", "ownroom", "PA185Q02JA", "PA166Q01HA",
    "PA188Q03JA", "PA005Q01TA", "HISEI"
]

# %%
# print data shape and explore misings
print("\n--- First Lines ---")
print(d.head())

print("\n--- Missings per variable ---")
missing = d.isna().sum().sort_values(ascending=False)
print(missing)

print("\n--- Missing rate (%) ---")
print((100 * d.isna().mean()).sort_values(ascending=False).round(2))
